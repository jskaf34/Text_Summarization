# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

sns.set()
# Out:
# [nltk_data] Downloading package wordnet to /Users/jskaf/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#read json file in pandas

df = pd.read_json('data/airbus_helicopters_train_set.json')
df.head()
# Out:
#                                                          train_sum01  \
# original_text      These general Standard Conditions of Sale appl...
# reference_summary  These terms and conditions apply as soon as th...
# uid                                                      train_sum01
#
#                                                         train_sum010  \
# original_text      Each Party represents to the other as at the d...
# reference_summary  Each Party represents that the other is not a ...
# uid                                                     train_sum010
#
#                                                        train_sum0100  \
# original_text      All living, travelling and accommodation expen...
# reference_summary  Expenses relating to the travelling, living an...
# uid                                                    train_sum0100
#
#                                                        train_sum0101  \
# original_text      Unless otherwise specified in the Contract, th...
# reference_summary  Unless otherwise specified in the Contract, th...
# uid                                                    train_sum0101
#
#                                                        train_sum0102  \
# original_text      Reasonable insurance coverage of risks arising...
# reference_summary  Reasonable insurance coverage of risks arising...
# uid                                                    train_sum0102
#
#                                                        train_sum0103  \
# original_text      Any change requested by the Customer shall be ...
# reference_summary  All the changes requested by the Customer are ...
# uid                                                    train_sum0103
#
#                                                        train_sum0104  \
# original_text      After receipt of the Order Confirmation, shoul...
# reference_summary  If the Customer decides to cancel a confirmed ...
# uid                                                    train_sum0104
#
#                                                        train_sum0105  \
# original_text      The Training Services shall be performed in ac...
# reference_summary  The Training Services are performed depending ...
# uid                                                    train_sum0105
#
#                                                        train_sum0106  \
# original_text      Should a trainee be late for or absent from an...
# reference_summary  If a trainee is late or absent from a course, ...
# uid                                                    train_sum0106
#
#                                                        train_sum0107  ...  \
# original_text      Changes to the training session planning reque...  ...
# reference_summary  Changes to the training session planning must ...  ...
# uid                                                    train_sum0107  ...
#
#                                                         train_sum090  \
# original_text      These SCS along with the applicable Specific A...
# reference_summary  These conditions supersede all previous commun...
# uid                                                     train_sum090
#
#                                                         train_sum091  \
# original_text      In the event that one (1) or more of the artic...
# reference_summary  If 1 or more articles of these conditions are ...
# uid                                                     train_sum091
#
#                                                         train_sum092  \
# original_text      English shall be the language of the Contract....
# reference_summary  English is the language of the Contract and sh...
# uid                                                     train_sum092
#
#                                                         train_sum093  \
# original_text      In case of any contradictions and discrepancie...
# reference_summary  The order of precedence is the following : Pur...
# uid                                                     train_sum093
#
#                                                         train_sum094  \
# original_text      The provisions of the confidentiality, intelle...
# reference_summary  The provisions regarding confidentiality, IP, ...
# uid                                                     train_sum094
#
#                                                         train_sum095  \
# original_text      No term or provision hereof will be considered...
# reference_summary  No term, provision or breach shall be waived o...
# uid                                                     train_sum095
#
#                                                         train_sum096  \
# original_text      Any variation or modification of the Contract ...
# reference_summary  Any modification to the contract shall be put ...
# uid                                                     train_sum096
#
#                                                         train_sum097  \
# original_text      The relationship between the Parties is solely...
# reference_summary  No joint venture or partnership is intended no...
# uid                                                     train_sum097
#
#                                                         train_sum098  \
# original_text      The Customer shall not be entitled, without th...
# reference_summary  Unless the Seller agrees to it through writing...
# uid                                                     train_sum098
#
#                                                         train_sum099
# original_text      This Specific Annex, subject to SCS, is applic...
# reference_summary  This annex is subject to the SCS and applies t...
# uid                                                     train_sum099
#
# [3 rows x 413 columns]

# %%
# transpose the dataframe

df = df.T
df.head()
# Out:
#                                                    original_text  \
# train_sum01    These general Standard Conditions of Sale appl...
# train_sum010   Each Party represents to the other as at the d...
# train_sum0100  All living, travelling and accommodation expen...
# train_sum0101  Unless otherwise specified in the Contract, th...
# train_sum0102  Reasonable insurance coverage of risks arising...
#
#                                                reference_summary  \
# train_sum01    These terms and conditions apply as soon as th...
# train_sum010   Each Party represents that the other is not a ...
# train_sum0100  Expenses relating to the travelling, living an...
# train_sum0101  Unless otherwise specified in the Contract, th...
# train_sum0102  Reasonable insurance coverage of risks arising...
#
#                          uid
# train_sum01      train_sum01
# train_sum010    train_sum010
# train_sum0100  train_sum0100
# train_sum0101  train_sum0101
# train_sum0102  train_sum0102

# %%
#reset the index

df = df.reset_index()
df.head()
# Out:
#            index                                      original_text  \
# 0    train_sum01  These general Standard Conditions of Sale appl...
# 1   train_sum010  Each Party represents to the other as at the d...
# 2  train_sum0100  All living, travelling and accommodation expen...
# 3  train_sum0101  Unless otherwise specified in the Contract, th...
# 4  train_sum0102  Reasonable insurance coverage of risks arising...
#
#                                    reference_summary            uid
# 0  These terms and conditions apply as soon as th...    train_sum01
# 1  Each Party represents that the other is not a ...   train_sum010
# 2  Expenses relating to the travelling, living an...  train_sum0100
# 3  Unless otherwise specified in the Contract, th...  train_sum0101
# 4  Reasonable insurance coverage of risks arising...  train_sum0102

# %%
#plot the ration length of original_text / length of reference_summary

df['ratio'] =  df['reference_summary'].apply(lambda x: len(x)) / df['original_text'].apply(lambda x: len(x))
df.head()

plt.plot(df['ratio'])

# %%
# show the row with the highest ratio

highest_ratio = df[df['ratio'] == df['ratio'].max()]
print("Original text: ", highest_ratio['original_text'].values[0])
print("Reference summary: ", highest_ratio['reference_summary'].values[0])
print("Name of the file: ", highest_ratio['index'].values[0])
# Out:
# Original text:  For Pratt & Whitney’s engine(s) the initial technical publication will be provided free of charge through web access.
# Reference summary:  For Pratt & Whitney’s engines, the initial technical publication is provided free of charge through web access. The request of hard copies is charged by the relevant manufacturer to the Customer if available.
# Name of the file:  train_sum0279

# %%
temp = df[df['ratio'] > 1]
len(temp)

# print names of the files with ratio > 1

for i in range(len(temp)):
    print(temp['index'].values[i])
# Out:
# train_sum0279
# train_sum0317

# %%
# Add a new column to the dataframe to store the length of the original text

df['length_original_text'] = df['original_text'].apply(lambda x: len(x))

# %%
#Sort the dataframe by the length of the original text and plot the length of the original text

df = df.sort_values(by='length_original_text')
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)

plt.plot(df['length_original_text'])

# %%
df["target"] = df["ratio"].apply(lambda x: 1 if x > 0.9 else 0)

# Plot the length of the original text, in red the rows with target = 1

plt.plot(df['length_original_text'])
plt.plot(df[df['target'] == 1]['length_original_text'], 'ro')

# %%
# Tokenize and preprocess
def preprocess(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    return tokens

# %%
def preprocess_lemma(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word.isalnum() and word not in stop_words]
    
    return tokens

# %%
# Build frequency dictionaries
entry_texts_freq = Counter()
summarizations_freq = Counter()

for entry_text, summarization in zip(df["original_text"], df["reference_summary"]):
    entry_texts_freq.update(preprocess(entry_text))
    summarizations_freq.update(preprocess(summarization))

# Calculate retention and erasure rates
retention_rates = {}
erasure_rates = {}

for word in entry_texts_freq:
    total_occurrences = entry_texts_freq[word]
    retention_rate = summarizations_freq[word] / total_occurrences if total_occurrences > 0 else 0
    erasure_rate = 1 - retention_rate
    retention_rates[word] = retention_rate
    erasure_rates[word] = erasure_rate

# %%
# Identify significant words (adjust thresholds as needed)
significant_words_kept = [word for word in retention_rates if retention_rates[word] > 0.8 and erasure_rates[word] < 0.2]
significant_words_erased = [word for word in retention_rates if retention_rates[word] < 0.2 and erasure_rates[word] > 0.8]

# %%
# Build frequency dictionaries
entry_texts_freq = Counter()
summarizations_freq = Counter()

for entry_text, summarization in zip(df["original_text"], df["reference_summary"]):
    entry_texts_freq.update(preprocess_lemma(entry_text))
    summarizations_freq.update(preprocess_lemma(summarization))

# Calculate retention and erasure rates
retention_rates_lemma = {}
erasure_rates_lemma = {}

for word in entry_texts_freq:
    total_occurrences = entry_texts_freq[word]
    retention_rate = summarizations_freq[word] / total_occurrences if total_occurrences > 0 else 0
    erasure_rate = 1 - retention_rate
    retention_rates_lemma[word] = retention_rate
    erasure_rates_lemma[word] = erasure_rate

# %%
significant_words_kept_lemma = [word for word in retention_rates_lemma if retention_rates_lemma[word] > 0.8 and erasure_rates_lemma[word] < 0.2]
significant_words_erased_lemma = [word for word in retention_rates_lemma if retention_rates_lemma[word] < 0.2 and erasure_rates_lemma[word] > 0.8]

# %%
# Visualize the results
# (You can use matplotlib, seaborn, or any other plotting library)

# Example: Bar chart for significant words kept
plt.figure(figsize=(20, 5))

plt.bar(significant_words_kept[:20], [retention_rates[word] for word in significant_words_kept][:20])
plt.xlabel('Words')
plt.ylabel('Retention Rate')
plt.title('Significant Words Kept in Summarizations')
plt.show()

# %%
plt.figure(figsize=(12, 5))
# Example: Bar chart for significant words erased
plt.bar(significant_words_erased[:10], [erasure_rates[word] for word in significant_words_erased][:10])
plt.xlabel('Words')
plt.ylabel('Erasure Rate')
plt.title('Significant Words Erased in Summarizations')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.bar(significant_words_kept_lemma[:20], [retention_rates_lemma[word] for word in significant_words_kept_lemma][:20])
plt.xlabel('Words')
plt.ylabel('Retention Rate')
plt.title('Significant Words Kept in Summarizations (Lemmatized)')
plt.show()
